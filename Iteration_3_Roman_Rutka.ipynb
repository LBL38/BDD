# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("gtfs_tag.db")
c = conn.cursor()

# %% [markdown]
# $\to$ télécharger les données depuis :
# https://www.data.gouv.fr/fr/datasets/horaires-theoriques-du-reseau-tag/
#
# $\to$ Dans le dossier "./SEM-GTFS"

# %% [markdown]
# # Importer agency et stops avec Pandas

# %%
agency = pd.read_csv("SEM-GTFS/agency.txt")
agency
# Out:
#   agency_id        agency_name                   agency_url agency_timezone  \
# 0       SEM  Mobilités M - Tag  https://www.mobilites-m.fr/    Europe/Paris
#
#   agency_lang  agency_phone
# 0          FR     438703870

# %%
stops = pd.read_csv("SEM-GTFS/stops.txt")
stops.head()
# Out:
#   stop_id stop_code                       stop_name  stop_lat  stop_lon  \
# 0    0004      0004      Meylan, Revirée - Sayettes  45.21220   5.76728
# 1    0006      0006      La Tronche, Commandant Nal  45.20323   5.74535
# 2    0007      0007        La Tronche, Musée Hébert  45.20564   5.74888
# 3    0008      0008  La Tronche, Centre Théologique  45.20617   5.75214
# 4    0011      0011                Meylan, Malacher  45.21128   5.78724
#
#    zone_id  location_type parent_station  wheelchair_boarding
# 0      NaN            NaN       REVIREES                    0
# 1      NaN            NaN       COMMANAL                    1
# 2      NaN            NaN       MUSHEBER                    1
# 3      NaN            NaN       CENTHEOL                    1
# 4      NaN            NaN       MALACHER                    1

# %%
agency.loc[:,["agency_id", "agency_name"]].to_sql("agency", con=conn, if_exists = "append", index= False)

# %%
stops.loc[:, ["stop_id", "stop_name", "stop_lat", 'stop_lon']].to_sql("Stops", con = conn, if_exists = "append", index = False)

# %% [markdown]
# # Bulk Insert :

# %%
# Étape 3.4.1 - implémenter une fonction qui génère une commande insertion SQL

def gen_insert_query(table_name, a_dict):
    cols = tuple(a_dict.keys())
    vals = tuple(a_dict.values())
    return f"INSERT INTO {table_name} {cols} VALUES {vals}"

# %%
## test de la fonction :

dicotest = {"stop_id" : 9999, "stop_name":"Ceci est un nom d'arrêt", "stop_lat":45.21220, 'stop_lon':5.75214}


print(gen_insert_query("table_name", dicotest))
# Out:
# INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES (9999, "Ceci est un nom d'arrêt", 45.2122, 5.75214)

# %%
# Étape 3.4.2 - implémenter une fonction qui génère des commandes d’insertion SQL

def get_insert_queries(table_name, df):
    querylist = []
    for row in range (len(df)):
        querylist.append(gen_insert_query(table_name, dict(df.iloc[row,:])))
    return querylist

# %%
## Test de la fonction : 

print(get_insert_queries("table_name", stops[["stop_id", "stop_name", "stop_lat", 'stop_lon']]))
# Out:
# ["INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0004', 'Meylan, Revirée - Sayettes', 45.2122, 5.76728)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0006', 'La Tronche, Commandant Nal', 45.20323, 5.74535)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0007', 'La Tronche, Musée Hébert', 45.20564, 5.74888)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0008', 'La Tronche, Centre Théologique', 45.20617, 5.75214)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0011', 'Meylan, Malacher', 45.21128, 5.78724)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0012', 'La Tronche, La Carronnerie Basse', 45.20094, 5.75814)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0015', 'Meylan, Granier', 45.21024, 5.78405)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0016', 'Meylan, Meylan Mairie', 45.20941, 5.77926)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0017', 'Meylan, Piscine des Buclos', 45.20883, 5.77503)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0018', 'Meylan, Le Brêt', 45.20598, 5.77184)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0019', 'Meylan, Le Brêt', 45.2059, 5.77174)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0021', 'Meylan, La Revirée', 45.20731, 5.7677)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0024', 'Grenoble, Victor Hugo', 45.19056, 5.72512)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0026', 'Meylan, Les Léchères', 45.20454, 5.75928)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0027', 'Meylan, Les Léchères', 45.20521, 5.75858)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0028', 'Meylan, Plaine Fleurie', 45.20268, 5.7609)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0029', 'Meylan, Les Jaillières', 45.22064, 5.78917)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0030', 'Meylan, Saint-Mury', 45.21947, 5.78613)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0031', 'Meylan, Bérivière', 45.21882, 5.78312)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0032', 'Meylan, Les Mûriers', 45.21605, 5.77947)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0033', 'Meylan, Chaumetière', 45.2124, 5.76983)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0034', 'Meylan, Saint-Jean Bosco', 45.21282, 5.77305)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0035', 'Meylan, Lycée du Grésivaudan - Bachais', 45.21416, 5.7791)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0036', 'Meylan, Montlivet', 45.22996, 5.78973)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0037', 'Domène, Domène Mairie', 45.20152, 5.83821)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0038', 'Domène, Les Mortes', 45.19636, 5.82887)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0039', 'Murianette, Le Bourg', 45.19186, 5.81663)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0040', 'Gières, La Perrière', 45.18902, 5.81006)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALUES ('0041', 'Murianette, La Perrière', 45.18971, 5.81173)", "INSERT INTO table_name ('stop_id', 'stop_name', 'stop_lat', 'stop_lon') VALU ...

# %%
# Étape 3.4.3 - implémenter une procédure qui crée un fichier SQL

def gen_insert_file(filename, table_name, df):
    filewriter = open(f"./Test/{filename}", "a")
    #filewriter.write("BEGIN TRANSACTION import_des_data; ")
    #filewriter.write(f"CREATE TABLE {table_name} {tuple(df.columns)}")
    liste = get_insert_queries(table_name, df)
    for line in range(len(liste)):
        filewriter.write(f"\n{liste[line]};")
    #filewriter.write("\nCOMMIT TRANSACTION import_des_data;")                
    filewriter.close()

# %%
# trips
trips = pd.read_csv("SEM-GTFS/trips.txt")
#trips = trips["trip_id", "trip_short_name", "route_id"]

# stoptimes
stoptimes = pd.read_csv("SEM-GTFS/stop_times.txt")
#stoptimes = stoptimes["trip_id", "stop_id", "arrival_time", "departure_time", "stop_sequence"]

# %%
gen_insert_file("Stops.sql", "Stops", stops)

# %%
gen_insert_file("Trips.sql", "Trips", trips)
gen_insert_file("Stop_Times.sql", "Stop_Times", stoptimes)
